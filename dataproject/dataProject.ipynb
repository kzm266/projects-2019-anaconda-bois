# %%
# %load_ext autoreload
# %autoreload 2
# You can load your python module as this:
import Project as pr
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pr.Difference('Province Fyn')
